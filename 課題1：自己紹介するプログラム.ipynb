# %%
name = "taro Kirameki"
age = 25
print("名前を入力してください:", name)
print("現在の年齢を入力してください:",age)
print("私の名前は", name, "です。来年で", age + 1, "歳になります。")
# Out:
# 名前を入力してください: taro Kirameki
# 現在の年齢を入力してください: 25
# 私の名前は taro Kirameki です。来年で 26 歳になります。

# %%
name = input("名前を入力してください:")
age = int(input("現在の年齢を入力してください"))

print("私の名前は", name,"です。来年で", age + 1,"歳になります。")
# Out:
# 私の名前は taro Kirameki です。来年で 26 歳になります。

# %%
print(f"私の名前は taro kirameki です。来年で 26 歳になります。")
# Out:
# 私の名前は taro kirameki です。来年で 26 歳になります。

# %%
age = 25
age = input("現在の年齢を入力してください")

# %%
name = "taro kirameki"
name = input("名前を入力してください")

# %%
name = input("名前を入力してください")

# %%
name = "taro Kiramekiko"
