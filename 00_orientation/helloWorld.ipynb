# %% [markdown]
# 上
#
# --------
#
# 下
# 上
#
# ---
#
# 下

# %% [markdown]
# 名前|年齢|性別
# -|-|-
# 佐藤|20|男
# 鈴木|25|女
# 高橋|8|男
#
#
# 名前|年齢|性別
# -|-|-
# 佐藤|20|男
# 鈴木|25|女
# 高橋|8|男

# %% [markdown]
# 1. 肉
# 1. 肉
#     1. 野菜
#         1. レタス
#          1. キャベツ
#     1. 根野菜
# 1. 果物

# %% [markdown]
# - 1行目
# - 2行目
#     - ネスト
#         - nesuto

# %% [markdown]
# # 見出し
# ## 見出し2
# ###### 見出し6

# %% [markdown]
# # レッスン0
# - VS Codeな基本的な書き方

# %%
print("Hello! World!")
print("こんにちは！ 世界！")
# Out:
# Hello! World!
# こんにちは！ 世界！
